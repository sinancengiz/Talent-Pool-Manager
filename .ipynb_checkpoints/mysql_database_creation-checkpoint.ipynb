# %%
# import necessary libraries
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()
engine = create_engine('mysql://localhost:3306', echo=False)

# %%
path = "Resources/data.xlsx"
employee_df = pd.read_excel(path)
employee_df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#            ...           RelationshipSatisfaction StandardHours  \
# 0          ...                                  1            80
# 1          ...                                  4            80
# 2          ...                                  2            80
# 3          ...                                  3            80
# 4          ...                                  4            80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                  8                      0               1
# 1                 1                 10                      3               3
# 2                 0                  7                      3               3
# 3                 0                  8                      3               3
# 4                 1                  6                      3               3
#
#    YearsAtCompany YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                  4                        0
# 1              10                  7                        1
# 2               0                  0                        0
# 3               8                  7                        3
# 4               2                  2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 35 columns]

# %%
employee_df.to_sql('employees', con=engine, index=True, index_label="id")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1192                 with util.safe_reraise():
# -> 1193                     self._dec_overflow()
#    1194         else:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1189             try:
# -> 1190                 return self._create_connection()
#    1191             except:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     670             self.starttime = time.time()
# --> 671             connection = pool._invoke_creator(self)
#     672             pool.logger.debug("Created new connection %r", connection)
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     409     def connect(self, *cargs, **cparams):
# --> 410         return self.dbapi.connect(*cargs, **cparams)
#     411
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pymysql\__init__.py in Connect(*args, **kwargs)
#      89     from .connections import Connection
# ---> 90     return Connection(*args, **kwargs)
#      91
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pymysql\connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, no_delay, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix)
#     698         else:
# --> 699             self.connect()
#     700
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     935             self._get_server_information()
# --> 936             self._request_authentication()
#     937
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pymysql\connections.py in _request_authentication(self)
#    1155         self.write_packet(data)
# -> 1156         auth_packet = self._read_packet()
#    1157
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#    1017         packet = packet_type(buff, self.encoding)
# -> 1018         packet.check_error()
#    1019         return packet
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pymysql\connections.py in check_error(self)
#     383             if DEBUG: print("errno =", errno)
# --> 384             err.raise_mysql_exception(self._data)
#     385
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     106     errorclass = error_map.get(errno, InternalError)
# --> 107     raise errorclass(errno, errval)
#
# OperationalError: (1045, "Access denied for user 'rwzlo'@'localhost' (using password: NO)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-13-b618136cb531> in <module>()
# ----> 1 employee_df.to_sql('employees', con=engine, index=True, index_label="id")
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, flavor, schema, if_exists, index, index_label, chunksize, dtype)
#    1532         sql.to_sql(self, name, con, flavor=flavor, schema=schema,
#    1533                    if_exists=if_exists, index=index, index_label=index_label,
# -> 1534                    chunksize=chunksize, dtype=dtype)
#    1535
#    1536     def to_pickle(self, path, compression='infer',
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, flavor, schema, if_exists, index, index_label, chunksize, dtype)
#     471     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     472                       index_label=index_label, schema=schema,
# --> 473                       chunksize=chunksize, dtype=dtype)
#     474
#     475
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1153                          if_exists=if_exists, index_label=index_label,
#    1154                          schema=schema, dtype=dtype)
# -> 1155         table.create()
#    1156         table.insert(chunksize)
#    1157         if (not name.isdigit() and not name.islower()):
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pandas\io\sql.py in create(self)
#     588
#     589     def create(self):
# --> 590         if self.exists():
#     591             if self.if_exists == 'fail':
#     592                 raise ValueError("Table '%s' already exists." % self.name)
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pandas\io\sql.py in exists(self)
#     576
#     577     def exists(self):
# --> 578         return self.pd_sql.has_table(self.name, self.schema)
#     579
#     580     def sql_schema(self):
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1181             self.connectable.dialect.has_table,
#    1182             name,
# -> 1183             schema or self.meta.schema,
#    1184         )
#    1185
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in run_callable(self, callable_, *args, **kwargs)
#    2053
#    2054         """
# -> 2055         with self.contextual_connect() as conn:
#    2056             return conn.run_callable(callable_, *args, **kwargs)
#    2057
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in contextual_connect(self, close_with_result, **kwargs)
#    2121         return self._connection_cls(
#    2122             self,
# -> 2123             self._wrap_pool_connect(self.pool.connect, None),
#    2124             close_with_result=close_with_result,
#    2125             **kwargs)
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2160             if connection is None:
#    2161                 Connection._handle_dbapi_exception_noconnection(
# -> 2162                     e, dialect, self)
#    2163             else:
#    2164                 util.reraise(*sys.exc_info())
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1474             util.raise_from_cause(
#    1475                 sqlalchemy_exception,
# -> 1476                 exc_info
#    1477             )
#    1478         else:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2156         dialect = self.dialect
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#    2160             if connection is None:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     401         """
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#     405         try:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     786     def _checkout(cls, pool, threadconns=None, fairy=None):
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#     790             fairy._pool = pool
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     530     @classmethod
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#     534             dbapi_connection = rec.get_connection()
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1191             except:
#    1192                 with util.safe_reraise():
# -> 1193                     self._dec_overflow()
#    1194         else:
#    1195             return self._do_get()
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      64             self._exc_info = None   # remove potential circular references
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#      68             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     185         if value.__traceback__ is not tb:
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#     189 else:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1188         if self._inc_overflow():
#    1189             try:
# -> 1190                 return self._create_connection()
#    1191             except:
#    1192                 with util.safe_reraise():
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     348         """Called by subclasses to create a new ConnectionRecord."""
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#     352     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     475         self.__pool = pool
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#     479
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     669         try:
#     670             self.starttime = time.time()
# --> 671             connection = pool._invoke_creator(self)
#     672             pool.logger.debug("Created new connection %r", connection)
#     673             self.connection = connection
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     104                         if connection is not None:
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#     108             creator = pop_kwarg('creator', connect)
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     408
#     409     def connect(self, *cargs, **cparams):
# --> 410         return self.dbapi.connect(*cargs, **cparams)
#     411
#     412     def create_connect_args(self, url):
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pymysql\__init__.py in Connect(*args, **kwargs)
#      88     """
#      89     from .connections import Connection
# ---> 90     return Connection(*args, **kwargs)
#      91
#      92 from . import connections as _orig_conn
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pymysql\connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, no_delay, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix)
#     697             self._sock = None
#     698         else:
# --> 699             self.connect()
#     700
#     701     def _create_ssl_ctx(self, sslp):
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     934
#     935             self._get_server_information()
# --> 936             self._request_authentication()
#     937
#     938             if self.sql_mode is not None:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pymysql\connections.py in _request_authentication(self)
#    1154
#    1155         self.write_packet(data)
# -> 1156         auth_packet = self._read_packet()
#    1157
#    1158         # if authentication method isn't accepted the first byte
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#    1016
#    1017         packet = packet_type(buff, self.encoding)
# -> 1018         packet.check_error()
#    1019         return packet
#    1020
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pymysql\connections.py in check_error(self)
#     382             errno = self.read_uint16()
#     383             if DEBUG: print("errno =", errno)
# --> 384             err.raise_mysql_exception(self._data)
#     385
#     386     def dump(self):
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     105         errval = data[3:].decode('utf-8', 'replace')
#     106     errorclass = error_map.get(errno, InternalError)
# --> 107     raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1045, "Access denied for user 'rwzlo'@'localhost' (using password: NO)") (Background on this error at: http://sqlalche.me/e/e3q8)
